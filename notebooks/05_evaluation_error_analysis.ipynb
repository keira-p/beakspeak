# %% [markdown]
# Purpose: understand where the model performs well or struggles.
#
# Expected contents:
#
# top-1 accuracy
# top-3 accuracy
# confusion patterns
# hardest classes
# misclassified examples
# maybe confidence analysis
#
# This is your “what is this model actually good at?” notebook.
