# %%
import mlflow
import random

# %%
mlflow.set_tracking_uri("file:///Users/keira/Documents/projects/beakspeak/mlruns")
mlflow.set_experiment("beakspeak")
# Out:
# /Users/keira/.pyenv/versions/3.10.6/envs/beakspeak-env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)
# 2026/04/07 19:49:21 INFO mlflow.tracking.fluent: Experiment with name 'beakspeak' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///Users/keira/Documents/projects/beakspeak/mlruns/291232564778632085', creation_time=1775587761737, experiment_id='291232564778632085', last_update_time=1775587761737, lifecycle_stage='active', name='beakspeak', tags={}, trace_location=None, workspace='default'>

# %%
with mlflow.start_run():

    model_name = "baseline_cnn"
    learning_rate = 0.001

    # Log params
    mlflow.log_param("model", model_name)
    mlflow.log_param("learning_rate", learning_rate)

    # Fake "training result"
    accuracy = random.uniform(0.6, 0.9)

    # Log metric
    mlflow.log_metric("accuracy", accuracy)

    print(f"Model: {model_name}, Accuracy: {accuracy}")
# Out:
# Model: baseline_cnn, Accuracy: 0.6613247676979007
